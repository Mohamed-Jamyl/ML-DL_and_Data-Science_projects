# %% [markdown]
# # <center><strong> Vlib (Bike rental) </strong></center>

# %%
from IPython.display import Image
Image(filename='bi.png')

# %% [markdown]
# ## <center><strong> Project Overview </strong></center>
#
# ### Bike share systems are a way to rent bikes where the process of obtaining membership, renting and returning bikes is automated through a network of kiosks located throughout the city. Through these systems, people can rent a bike from one location and return it to another location based on their needs. Currently, there are more than 500 bike share programs around the world.
#
#
# #### datetime: Date and time in timestamp
# #### season: 4 = summer, 3 = spring, 2 = autumn, 1 = winter
# #### holiday: If considered as vacation then 1 otherwise 0
# #### workingday: If the day is neither a weekend nor a vacation day
#
# ### weather:
# #### 1: Clear, Few clouds, Partly cloudy, Partly cloudy
# #### 2: Fog + clouds, Fog + broken clouds, Fog + some clouds, Fog
# #### 3: Light snow, light rain + thunderstorm + scattered clouds, light rain + scattered clouds
# #### 4: Heavy rain + ice vanes + thunderstorm + mist, snow + fog
#
# #### temp: temperature in degrees Celsius
# #### atemp: temperature felt in degrees Celsius
# #### humidity: relative humidity
# #### windspeed: wind speed
# #### casual: number of non-subscribed users
# #### registered: number of subscribed users
# #### count: total number of users

# %% [markdown]
# ----------------------------------
# ----------------------------------

# %% [markdown]
# ## <center><strong> Import Libraries </strong></center>

# %%
import pylab
import calendar

import numpy as np
import pandas as pd
import seaborn as sn
from scipy import stats
import math
from datetime import datetime
import matplotlib.pyplot as plt
import warnings
from IPython.display import Image


pd.options.mode.chained_assignment = None
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# ----------------------------------
# ----------------------------------

# %% [markdown]
# ## <center><strong>Exploratory Data Analysis (EDA)</strong></center>

# %%
df = pd.read_csv("vlib.csv")
df.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
df.shape
# Out:
# (10886, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %%
df.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# std        8.474601     19.245033      8.164537     49.960477    151.039033
# min        0.760000      0.000000      0.000000      0.000000      0.000000
# 25%       16.665000     47.000000      7.001500      4.000000     36.000000
# 50%       24.240000     62.000000     12.998000     17.000000    118.000000
# 75%       31.060000     77.000000     16.997900     49.000000    222.000000
# max       45.455000    100.000000     56.996900    367.000000    886.000000
#
#               count
# count  10886.000000
# mean     191.574132
# std      181.144454
# min        1.000000
# 25%       42.000000
# 50%      145.000000
# 75%      284.000000
# max      977.000000

# %%
df.tail()
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# 10881  19.695        50    26.0027       7         329    336
# 10882  17.425        57    15.0013      10         231    241
# 10883  15.910        61    15.0013       4         164    168
# 10884  17.425        61     6.0032      12         117    129
# 10885  16.665        66     8.9981       4          84     88

# %%
df.columns
# Out:
# Index(['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp',
#        'atemp', 'humidity', 'windspeed', 'casual', 'registered', 'count'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# df.isnull().sum()
for i in df.columns:
    print(i," : ",df[i].isnull().sum())
# Out:
# datetime  :  0
# season  :  0
# holiday  :  0
# workingday  :  0
# weather  :  0
# temp  :  0
# atemp  :  0
# humidity  :  0
# windspeed  :  0
# casual  :  0
# registered  :  0
# count  :  0

# %%
list_variables = ["datetime","season","weather","holiday","workingday"]

# %%
"2011-01-01 00:00:00".split()
# Out:
# ['2011-01-01', '00:00:00']

# %%
df["date"] = df.datetime.apply(lambda x : x.split()[0])
df["date"].head()
# Out:
# 0    2011-01-01
# 1    2011-01-01
# 2    2011-01-01
# 3    2011-01-01
# 4    2011-01-01
# Name: date, dtype: object

# %%
df["hour"] = df.datetime.apply(lambda x : x.split()[1])
df["hour"].head()
# Out:
# 0    00:00:00
# 1    01:00:00
# 2    02:00:00
# 3    03:00:00
# 4    04:00:00
# Name: hour, dtype: object

# %%
df["hour"] = df.datetime.apply(lambda x : x.split()[1].split(":")[0])
df["hour"].head()
# Out:
# 0    00
# 1    01
# 2    02
# 3    03
# 4    04
# Name: hour, dtype: object

# %%
datetime.strptime("2011-01-01","%Y-%m-%d").weekday()
# Out:
# 5

# %%
calendar.day_name[datetime.strptime("2011-01-01","%Y-%m-%d").weekday()]
# Out:
# 'Saturday'

# %%
df["weekday"] = df.date.apply(lambda x : calendar.day_name[datetime.strptime(x,"%Y-%m-%d").weekday()])
df["month"] = df.date.apply(lambda x : calendar.month_name[datetime.strptime(x,"%Y-%m-%d").month])

# %%
df["weekday"].head()
# Out:
# 0    Saturday
# 1    Saturday
# 2    Saturday
# 3    Saturday
# 4    Saturday
# Name: weekday, dtype: object

# %%
df["month"].head()
# Out:
# 0    January
# 1    January
# 2    January
# 3    January
# 4    January
# Name: month, dtype: object

# %%
dictionnaire_saisons = {2: "Spring", 3 : "Summer", 4 : "Fall", 1 :"Winter" }
df["season"] = df.season.map(dictionnaire_saisons)

df["weather"] = df.weather.map({1: " Clear + Few clouds + Partly cloudy + Partly cloudy",\
                                        2 : " Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist ", \
                                        3 : " Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds", \
                                        4 :" Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog " })

# %%
df.head()
# Out:
#               datetime  season  holiday  workingday  \
# 0  2011-01-01 00:00:00  Winter        0           0
# 1  2011-01-01 01:00:00  Winter        0           0
# 2  2011-01-01 02:00:00  Winter        0           0
# 3  2011-01-01 03:00:00  Winter        0           0
# 4  2011-01-01 04:00:00  Winter        0           0
#
#                                              weather  temp   atemp  humidity  \
# 0   Clear + Few clouds + Partly cloudy + Partly c...  9.84  14.395        81
# 1   Clear + Few clouds + Partly cloudy + Partly c...  9.02  13.635        80
# 2   Clear + Few clouds + Partly cloudy + Partly c...  9.02  13.635        80
# 3   Clear + Few clouds + Partly cloudy + Partly c...  9.84  14.395        75
# 4   Clear + Few clouds + Partly cloudy + Partly c...  9.84  14.395        75
#
#    windspeed  casual  registered  count        date hour   weekday    month
# 0        0.0       3          13     16  2011-01-01   00  Saturday  January
# 1        0.0       8          32     40  2011-01-01   01  Saturday  January
# 2        0.0       5          27     32  2011-01-01   02  Saturday  January
# 3        0.0       3          10     13  2011-01-01   03  Saturday  January
# 4        0.0       0           1      1  2011-01-01   04  Saturday  January

# %%
categoryVariableList = ["hour","weekday","month","season","weather","holiday","workingday"]

for var in categoryVariableList:
    df[var] = df[var].astype("category")

# %%
df=df.drop(["datetime"],axis=1)

# %%
df.head()
# Out:
#    season holiday workingday  \
# 0  Winter       0          0
# 1  Winter       0          0
# 2  Winter       0          0
# 3  Winter       0          0
# 4  Winter       0          0
#
#                                              weather  temp   atemp  humidity  \
# 0   Clear + Few clouds + Partly cloudy + Partly c...  9.84  14.395        81
# 1   Clear + Few clouds + Partly cloudy + Partly c...  9.02  13.635        80
# 2   Clear + Few clouds + Partly cloudy + Partly c...  9.02  13.635        80
# 3   Clear + Few clouds + Partly cloudy + Partly c...  9.84  14.395        75
# 4   Clear + Few clouds + Partly cloudy + Partly c...  9.84  14.395        75
#
#    windspeed  casual  registered  count        date hour   weekday    month
# 0        0.0       3          13     16  2011-01-01   00  Saturday  January
# 1        0.0       8          32     40  2011-01-01   01  Saturday  January
# 2        0.0       5          27     32  2011-01-01   02  Saturday  January
# 3        0.0       3          10     13  2011-01-01   03  Saturday  January
# 4        0.0       0           1      1  2011-01-01   04  Saturday  January

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      10886 non-null  category
#  1   holiday     10886 non-null  category
#  2   workingday  10886 non-null  category
#  3   weather     10886 non-null  category
#  4   temp        10886 non-null  float64
#  5   atemp       10886 non-null  float64
#  6   humidity    10886 non-null  int64
#  7   windspeed   10886 non-null  float64
#  8   casual      10886 non-null  int64
#  9   registered  10886 non-null  int64
#  10  count       10886 non-null  int64
#  11  date        10886 non-null  object
#  12  hour        10886 non-null  category
#  13  weekday     10886 non-null  category
#  14  month       10886 non-null  category
# dtypes: category(7), float64(3), int64(4), object(1)
# memory usage: 757.0+ KB

# %%
fig, axes = plt.subplots(nrows=1,ncols=1)
fig.set_size_inches(8, 8)
sn.boxplot(data=df,y="count",orient="v",ax=axes)

axes.set(ylabel='Count',title="Box Plot On Count")
plt.show()

# %%
fig, axes = plt.subplots(nrows=1,ncols=1)
fig.set_size_inches(8, 8)
sn.boxplot(data=df,y="count",x="season",orient="v",ax=axes)
axes.set(xlabel='Season', ylabel='Count',title="Box Plot On Count Across Season")
plt.show()

# %%
fig, axes = plt.subplots(nrows=1,ncols=1)
fig.set_size_inches(8, 8)
sn.boxplot(data=df,y="count",x="hour",orient="v",ax=axes)
axes.set(xlabel='Hour Of The Day', ylabel='Count',title="Box Plot On Count Across Hour Of The Day")
plt.show()

# %%
fig, axes = plt.subplots(nrows=1,ncols=1)
fig.set_size_inches(8, 8)
sn.boxplot(data=df,y="count",x="workingday",orient="v",ax=axes)
axes.set(xlabel='Working Day', ylabel='Count',title="Box Plot On Count Across Working Day")
plt.show()

# %%
df.hist(rwidth=0.9)
plt.tight_layout()

# %% [markdown]
# - **visualise continuous features vs cnt (y)**
# - **plt.tight_layout() : fix distribution**

# %%
plt.title('temp vs count')
plt.scatter(df['temp'],df['count'],s=2)
plt.tight_layout()

# %%
plt.title('atemp vs count')
plt.scatter(df['atemp'],df['count'],s=2,c='m')
plt.tight_layout()

# %%
plt.title('humidity vs count')
plt.scatter(df['humidity'],df['count'],s=2,c='g')
plt.tight_layout()

# %%
plt.title('windspeed vs cnt')
plt.scatter(df['windspeed'],df['count'],s=2,c='c')
plt.tight_layout()

# %%
df.head()
# Out:
#    season holiday workingday  \
# 0  Winter       0          0
# 1  Winter       0          0
# 2  Winter       0          0
# 3  Winter       0          0
# 4  Winter       0          0
#
#                                              weather  temp   atemp  humidity  \
# 0   Clear + Few clouds + Partly cloudy + Partly c...  9.84  14.395        81
# 1   Clear + Few clouds + Partly cloudy + Partly c...  9.02  13.635        80
# 2   Clear + Few clouds + Partly cloudy + Partly c...  9.02  13.635        80
# 3   Clear + Few clouds + Partly cloudy + Partly c...  9.84  14.395        75
# 4   Clear + Few clouds + Partly cloudy + Partly c...  9.84  14.395        75
#
#    windspeed  casual  registered  count        date hour   weekday    month
# 0        0.0       3          13     16  2011-01-01   00  Saturday  January
# 1        0.0       8          32     40  2011-01-01   01  Saturday  January
# 2        0.0       5          27     32  2011-01-01   02  Saturday  January
# 3        0.0       3          10     13  2011-01-01   03  Saturday  January
# 4        0.0       0           1      1  2011-01-01   04  Saturday  January

# %%
df["season"].unique()
# Out:
# ['Winter', 'Spring', 'Summer', 'Fall']
# Categories (4, object): ['Fall', 'Spring', 'Summer', 'Winter']

# %%
df['count'].describe()
# Out:
# count    10886.000000
# mean       191.574132
# std        181.144454
# min          1.000000
# 25%         42.000000
# 50%        145.000000
# 75%        284.000000
# max        977.000000
# Name: count, dtype: float64

# %%
df['count'].quantile([0.01,.05,.15,.5,.95,.99])
# Out:
# 0.01      2.00
# 0.05      5.00
# 0.15     16.00
# 0.50    145.00
# 0.95    563.75
# 0.99    774.15
# Name: count, dtype: float64

# %%
df.shape[0] - df[np.abs(df["count"] - df["count"].mean()) <= (3 * df["count"].std())].shape[0]
# Out:
# 147

# %%
df_without_outliers = df[
    np.abs(df["count"] - df["count"].mean()) <= (3 * df["count"].std())
]

# %%
print ("Shape Of The Before Ouliers: ",df.shape)
print ("Shape Of The After Ouliers: ",df_without_outliers.shape)
# Out:
# Shape Of The Before Ouliers:  (10886, 15)
# Shape Of The After Ouliers:  (10739, 15)

# %% [markdown]
# ### Correlation

# %%
sn.heatmap(df.select_dtypes(include='number').corr(), annot=True)
plt.show()

# %%
fig,ax = plt.subplots()
fig.set_size_inches(12, 5)
sn.regplot(x="registered", y="count", data=df,ax=ax)
plt.show()

# %%
sortOrder = ["January","February","March","April","May","June","July","August","September","October","November","December"]
hueOrder = ["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"]

monthAggregated = pd.DataFrame(df.groupby("month")["count"].mean()).reset_index()
# Out:
# C:\Users\RPC\AppData\Local\Temp\ipykernel_1520\1024965024.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   monthAggregated = pd.DataFrame(df.groupby("month")["count"].mean()).reset_index()

# %%
fig,ax= plt.subplots()
fig.set_size_inches(12,5)

sn.barplot(data=monthAggregated,x="month",y="count",ax=ax,order=sortOrder)
ax.set(xlabel='Month', ylabel='Avearage Count',title="Average Count By Month")
plt.show()

# %%
hourAggregated = pd.DataFrame(df.groupby(["hour","season"],sort=True)["count"].mean()).reset_index()
# Out:
# C:\Users\RPC\AppData\Local\Temp\ipykernel_1520\43914173.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   hourAggregated = pd.DataFrame(df.groupby(["hour","season"],sort=True)["count"].mean()).reset_index()

# %%
fig,ax= plt.subplots()
fig.set_size_inches(12,5)
sn.pointplot(x=hourAggregated["hour"], y=hourAggregated["count"],hue=hourAggregated["season"], data=hourAggregated, join=True,ax=ax)
ax.set(xlabel='Hour Of The Day', ylabel='Users Count',title="Average Users Count By Hour Of The Day Across Season",label='big')
plt.show()
# Out:
# C:\Users\RPC\AppData\Local\Temp\ipykernel_1520\1048959242.py:3: UserWarning:
#
# The `join` parameter is deprecated and will be removed in v0.15.0.
#
#   sn.pointplot(x=hourAggregated["hour"], y=hourAggregated["count"],hue=hourAggregated["season"], data=hourAggregated, join=True,ax=ax)

# %%
hourAggregated = pd.DataFrame(df.groupby(["hour","weekday"],sort=True)["count"].mean()).reset_index()
# Out:
# C:\Users\RPC\AppData\Local\Temp\ipykernel_1520\2545632590.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   hourAggregated = pd.DataFrame(df.groupby(["hour","weekday"],sort=True)["count"].mean()).reset_index()

# %%
fig,ax= plt.subplots()
fig.set_size_inches(12,5)

sn.pointplot(x=hourAggregated["hour"], y=hourAggregated["count"],hue=hourAggregated["weekday"],hue_order=hueOrder, data=hourAggregated, join=True,ax=ax)
ax.set(xlabel='Hour Of The Day', ylabel='Users Count',title="Average Users Count By Hour Of The Day Across Weekdays",label='big')
plt.show()
# Out:
# C:\Users\RPC\AppData\Local\Temp\ipykernel_1520\2300106539.py:4: UserWarning:
#
# The `join` parameter is deprecated and will be removed in v0.15.0.
#
#   sn.pointplot(x=hourAggregated["hour"], y=hourAggregated["count"],hue=hourAggregated["weekday"],hue_order=hueOrder, data=hourAggregated, join=True,ax=ax)

# %%
hourTransformed = pd.melt(df[["hour","casual","registered"]], id_vars=['hour'], value_vars=['casual', 'registered'])
hourAggregated = pd.DataFrame(hourTransformed.groupby(["hour","variable"],sort=True)["value"].mean()).reset_index()
hourAggregated.head()
# Out:
# C:\Users\RPC\AppData\Local\Temp\ipykernel_1520\3219632994.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   hourAggregated = pd.DataFrame(hourTransformed.groupby(["hour","variable"],sort=True)["value"].mean()).reset_index()
#   hour    variable      value
# 0   00      casual  10.312088
# 1   00  registered  44.826374
# 2   01      casual   6.513216
# 3   01  registered  27.345815
# 4   02      casual   4.819196

# %%
fig,ax= plt.subplots()
fig.set_size_inches(12,5)

sn.pointplot(x=hourAggregated["hour"], y=hourAggregated["value"],hue=hourAggregated["variable"],hue_order=["casual","registered"], data=hourAggregated, join=True,ax=ax)
ax.set(xlabel='Hour Of The Day', ylabel='Users Count',title="Average Users Count By Hour Of The Day Across User Type",label='big')
plt.show()
# Out:
# C:\Users\RPC\AppData\Local\Temp\ipykernel_1520\2979321055.py:4: UserWarning:
#
# The `join` parameter is deprecated and will be removed in v0.15.0.
#
#   sn.pointplot(x=hourAggregated["hour"], y=hourAggregated["value"],hue=hourAggregated["variable"],hue_order=["casual","registered"], data=hourAggregated, join=True,ax=ax)

# %%
dropFeatures = ["casual","date","registered"]
df = df.drop(dropFeatures, axis=1)

# %%
df.head()
# Out:
#    season holiday workingday  \
# 0  Winter       0          0
# 1  Winter       0          0
# 2  Winter       0          0
# 3  Winter       0          0
# 4  Winter       0          0
#
#                                              weather  temp   atemp  humidity  \
# 0   Clear + Few clouds + Partly cloudy + Partly c...  9.84  14.395        81
# 1   Clear + Few clouds + Partly cloudy + Partly c...  9.02  13.635        80
# 2   Clear + Few clouds + Partly cloudy + Partly c...  9.02  13.635        80
# 3   Clear + Few clouds + Partly cloudy + Partly c...  9.84  14.395        75
# 4   Clear + Few clouds + Partly cloudy + Partly c...  9.84  14.395        75
#
#    windspeed  count hour   weekday    month
# 0        0.0     16   00  Saturday  January
# 1        0.0     40   01  Saturday  January
# 2        0.0     32   02  Saturday  January
# 3        0.0     13   03  Saturday  January
# 4        0.0      1   04  Saturday  January

# %%
df = pd.get_dummies(df,columns=["holiday"])
df = pd.get_dummies(df,columns=["weekday"])
df = pd.get_dummies(df,columns=["month"])
df = pd.get_dummies(df,columns=["season"])
df = pd.get_dummies(df,columns=["weather"])
df.columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 36 columns):
#  #   Column                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                            --------------  -----
#  0   workingday                                                                                        10886 non-null  category
#  1   temp                                                                                              10886 non-null  float64
#  2   atemp                                                                                             10886 non-null  float64
#  3   humidity                                                                                          10886 non-null  int64
#  4   windspeed                                                                                         10886 non-null  float64
#  5   count                                                                                             10886 non-null  int64
#  6   hour                                                                                              10886 non-null  category
#  7   holiday_0                                                                                         10886 non-null  bool
#  8   holiday_1                                                                                         10886 non-null  bool
#  9   weekday_Friday                                                                                    10886 non-null  bool
#  10  weekday_Monday                                                                                    10886 non-null  bool
#  11  weekday_Saturday                                                                                  10886 non-null  bool
#  12  weekday_Sunday                                                                                    10886 non-null  bool
#  13  weekday_Thursday                                                                                  10886 non-null  bool
#  14  weekday_Tuesday                                                                                   10886 non-null  bool
#  15  weekday_Wednesday                                                                                 10886 non-null  bool
#  16  month_April                                                                                       10886 non-null  bool
#  17  month_August                                                                                      10886 non-null  bool
#  18  month_December                                                                                    10886 non-null  bool
#  19  month_February                                                                                    10886 non-null  bool
#  20  month_January                                                                                     10886 non-null  bool
#  21  month_July                                                                                        10886 non-null  bool
#  22  month_June                                                                                        10886 non-null  bool
#  23  month_March                                                                                       10886 non-null  bool
#  24  month_May                                                                                         10886 non-null  bool
#  25  month_November                                                                                    10886 non-null  bool
#  26  month_October                                                                                     10886 non-null  bool
#  27  month_September                                                                                   10886 non-null  bool
#  28  season_Fall                                                                                       10886 non-null  bool
#  29  season_Spring                                                                                     10886 non-null  bool
#  30  season_Summer                                                                                     10886 non-null  bool
#  31  season_Winter                                                                                     10886 non-null  bool
#  32  weather_ Clear + Few clouds + Partly cloudy + Partly cloudy                                       10886 non-null  bool
#  33  weather_ Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog                               10886 non-null  bool
#  34  weather_ Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds  10886 non-null  bool
#  35  weather_ Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist                             10886 non-null  bool
# dtypes: bool(29), category(2), float64(3), int64(2)
# memory usage: 755.8 KB

# %% [markdown]
# ------------------------------
# ------------------------------

# %% [markdown]
# ## <center><strong>Creating Model</strong></center>

# %%
import sklearn
from sklearn.model_selection import train_test_split

X = df.drop('count', axis=1)
Y = df['count']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2,random_state=1234)

# %%
print(X_train.shape, X_test.shape)
print(Y_train.shape, Y_test.shape)
# Out:
# (8708, 35) (2178, 35)
# (8708,) (2178,)

# %%
from sklearn import metrics

def rmse(y, y_):
    return np.sqrt(np.mean((y-y_)**2))

def mae(y, y_):
    return np.mean(np.abs(y-y_))

# %%
from sklearn.dummy import DummyRegressor

dummy_regr = DummyRegressor(strategy = "mean")

dummy_regr.fit(X_train, Y_train)
y_pred = dummy_regr.predict(X_test)
print("R2: ", metrics.r2_score(Y_test, y_pred))
print("MAE: ", mae(Y_test, y_pred))
# Out:
# R2:  -0.0001091323812494327
# MAE:  140.67305071426674

# %%
from sklearn.linear_model import LinearRegression

lModel = LinearRegression()
lModel.fit(X=X_train, y=Y_train)
y_pred = lModel.predict(X_test)

print("R2: ", metrics.r2_score(Y_test, y_pred))
print("MAE: ", mae(Y_test, y_pred))
# Out:
# R2:  0.36341724707335255
# MAE:  105.39556770202667

# %%
plt.scatter(Y_test, y_pred, color='b')
plt.show()
