# %% [markdown]
# # <center><strong>Obesity risk</strong></center>

# %% [markdown]
# ###### **By Mohamed Jamyl**

# %%
from IPython.display import Image
Image(filename='obe.jpg')

# %% [markdown]
# ## <center><strong>Project Overview </strong></center>
#
# ### This Kaggle dataset provides comprehensive information on individuals, encompassing key attributes such as gender, age, height, weight, family history with overweight, dietary habits, physical activity, transportation mode, and the corresponding obesity level. The dataset is meticulously curated for research and analysis in the domain of health and lifestyle studies.nting obesity level)

# %% [markdown]
# ### Gender
# ### Age
# ### Height
# ### Weight
# ### Family_history_with_overweight
# ### FAVC (Frequent consumption of high-caloric food)
# ### FCVC (Frequency of consumption of vegetables)
# ### NCP (Number of main meals)
# ### CAEC (Consumption of food between meals)
# ### SMOKE
# ### CH2O (Daily water consumption)
# ### SCC (Caloric beverages consumption)
# ### FAF (Physical activity frequency)
# ### TUE (Time spent using technological devices)
# ### CALC (Consumption of alcohol)
# ### MTRANS (Mode of transportation)
# ### 0be1dad (Target variable representing obesity level)

# %% [markdown]
# --------------------------------------
# --------------------------------------
# --------------------------------------

# %% [markdown]
# ## **Import Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# from sklearn.model_selection import train_test_split, GridSearchCV
# from sklearn.preprocessing import LabelEncoder,StandardScaler
# from sklearn.metrics import classification_report


# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.linear_model import LogisticRegression
# from sklearn.svm import SVC
# from xgboost import XGBClassifier
# from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
# from sklearn.naive_bayes import GaussianNB 


import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# --------------------------------
# --------------------------------
# -------------------------------

# %% [markdown]
# ## **Exploratory Data Analysis (EDA)**

# %% [markdown]
# ### **Initial Data Understanding**

# %% [markdown]
#  - **Data loading and Inspection**
#  - **Data Types**
#  - **Missing Values**
#  - **Duplicates**

# %%
train_df= pd.read_csv('train_obesity.csv')
test_df= pd.read_csv('test_obesity.csv')

# %%
train_df.head()
# Out:
#    id  Gender        Age    Height      Weight family_history_with_overweight  \
# 0   0    Male  24.443011  1.699998   81.669950                            yes
# 1   1  Female  18.000000  1.560000   57.000000                            yes
# 2   2  Female  18.000000  1.711460   50.165754                            yes
# 3   3  Female  20.952737  1.710730  131.274851                            yes
# 4   4    Male  31.641081  1.914186   93.798055                            yes
#
#   FAVC      FCVC       NCP        CAEC SMOKE      CH2O SCC       FAF  \
# 0  yes  2.000000  2.983297   Sometimes    no  2.763573  no  0.000000
# 1  yes  2.000000  3.000000  Frequently    no  2.000000  no  1.000000
# 2  yes  1.880534  1.411685   Sometimes    no  1.910378  no  0.866045
# 3  yes  3.000000  3.000000   Sometimes    no  1.674061  no  1.467863
# 4  yes  2.679664  1.971472   Sometimes    no  1.979848  no  1.967973
#
#         TUE       CALC                 MTRANS           NObeyesdad
# 0  0.976473  Sometimes  Public_Transportation  Overweight_Level_II
# 1  1.000000         no             Automobile        Normal_Weight
# 2  1.673584         no  Public_Transportation  Insufficient_Weight
# 3  0.780199  Sometimes  Public_Transportation     Obesity_Type_III
# 4  0.931721  Sometimes  Public_Transportation  Overweight_Level_II

# %%
train_df.sample(10)
# Out:
#           id  Gender        Age    Height      Weight  \
# 19309  19309    Male  22.815416  1.741377   96.303855
# 10945  10945    Male  23.000000  1.780000   79.000000
# 7919    7919  Female  21.282238  1.774207  133.946080
# 18988  18988    Male  28.404332  1.788239  113.234349
# 11248  11248    Male  25.380557  1.775580  117.631707
# 7271    7271    Male  21.000000  1.620000   70.000000
# 12560  12560    Male  18.729566  1.734832   80.000000
# 18802  18802    Male  34.000000  1.700000   84.000000
# 2213    2213    Male  21.001969  1.722396   78.370039
# 17012  17012    Male  30.242597  1.779049  112.010504
#
#       family_history_with_overweight FAVC      FCVC       NCP        CAEC  \
# 19309                            yes  yes  2.000000  3.000000   Sometimes
# 10945                             no  yes  2.000000  3.000000  Frequently
# 7919                             yes  yes  3.000000  3.000000   Sometimes
# 18988                            yes  yes  2.002796  3.000000   Sometimes
# 11248                            yes  yes  2.630401  3.000000   Sometimes
# 7271                              no  yes  2.000000  1.000000          no
# 12560                            yes  yes  2.000000  2.965494   Sometimes
# 18802                            yes  yes  2.000000  3.000000   Sometimes
# 2213                             yes   no  1.570089  3.000000   Sometimes
# 17012                            yes  yes  1.999530  3.000000   Sometimes
#
#       SMOKE      CH2O SCC       FAF       TUE        CALC  \
# 19309    no  2.000000  no  2.698874  1.000000          no
# 10945    no  2.000000  no  2.000000  2.000000  Frequently
# 7919     no  1.221281  no  1.686229  0.965464   Sometimes
# 18988    no  2.000000  no  0.000000  1.415536   Sometimes
# 11248    no  2.184707  no  1.076720  0.000000   Sometimes
# 7271     no  2.000000  no  1.000000  0.000000  Frequently
# 12560    no  1.362583  no  1.000000  1.554404          no
# 18802    no  3.000000  no  3.000000  0.000000          no
# 2213     no  1.225958  no  1.582428  1.441605          no
# 17012    no  2.067741  no  1.926308  0.063005          no
#
#                       MTRANS           NObeyesdad
# 19309  Public_Transportation       Obesity_Type_I
# 10945  Public_Transportation        Normal_Weight
# 7919   Public_Transportation     Obesity_Type_III
# 18988             Automobile      Obesity_Type_II
# 11248  Public_Transportation      Obesity_Type_II
# 7271   Public_Transportation   Overweight_Level_I
# 12560  Public_Transportation  Overweight_Level_II
# 18802             Automobile  Overweight_Level_II
# 2213   Public_Transportation  Overweight_Level_II
# 17012             Automobile      Obesity_Type_II

# %%
train_df.tail()
# Out:
#           id Gender        Age    Height      Weight  \
# 20753  20753   Male  25.137087  1.766626  114.187096
# 20754  20754   Male  18.000000  1.710000   50.000000
# 20755  20755   Male  20.101026  1.819557  105.580491
# 20756  20756   Male  33.852953  1.700000   83.520113
# 20757  20757   Male  26.680376  1.816547  118.134898
#
#       family_history_with_overweight FAVC      FCVC       NCP        CAEC  \
# 20753                            yes  yes  2.919584  3.000000   Sometimes
# 20754                             no  yes  3.000000  4.000000  Frequently
# 20755                            yes  yes  2.407817  3.000000   Sometimes
# 20756                            yes  yes  2.671238  1.971472   Sometimes
# 20757                            yes  yes  3.000000  3.000000   Sometimes
#
#       SMOKE      CH2O SCC       FAF       TUE       CALC  \
# 20753    no  2.151809  no  1.330519  0.196680  Sometimes
# 20754    no  1.000000  no  2.000000  1.000000  Sometimes
# 20755    no  2.000000  no  1.158040  1.198439         no
# 20756    no  2.144838  no  0.000000  0.973834         no
# 20757    no  2.003563  no  0.684487  0.713823  Sometimes
#
#                       MTRANS           NObeyesdad
# 20753  Public_Transportation      Obesity_Type_II
# 20754  Public_Transportation  Insufficient_Weight
# 20755  Public_Transportation      Obesity_Type_II
# 20756             Automobile  Overweight_Level_II
# 20757  Public_Transportation      Obesity_Type_II

# %%
train_df.shape
# Out:
# (20758, 18)

# %%
test_df.shape
# Out:
# (13840, 17)

# %%
train_df.columns
# Out:
# Index(['id', 'Gender', 'Age', 'Height', 'Weight',
#        'family_history_with_overweight', 'FAVC', 'FCVC', 'NCP', 'CAEC',
#        'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE', 'CALC', 'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %%
test_df.columns
# Out:
# Index(['id', 'Gender', 'Age', 'Height', 'Weight',
#        'family_history_with_overweight', 'FAVC', 'FCVC', 'NCP', 'CAEC',
#        'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE', 'CALC', 'MTRANS'],
#       dtype='object')

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20758 entries, 0 to 20757
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              20758 non-null  int64
#  1   Gender                          20758 non-null  object
#  2   Age                             20758 non-null  float64
#  3   Height                          20758 non-null  float64
#  4   Weight                          20758 non-null  float64
#  5   family_history_with_overweight  20758 non-null  object
#  6   FAVC                            20758 non-null  object
#  7   FCVC                            20758 non-null  float64
#  8   NCP                             20758 non-null  float64
#  9   CAEC                            20758 non-null  object
#  10  SMOKE                           20758 non-null  object
#  11  CH2O                            20758 non-null  float64
#  12  SCC                             20758 non-null  object
#  13  FAF                             20758 non-null  float64
#  14  TUE                             20758 non-null  float64
#  15  CALC                            20758 non-null  object
#  16  MTRANS                          20758 non-null  object
#  17  NObeyesdad                      20758 non-null  object
# dtypes: float64(8), int64(1), object(9)
# memory usage: 2.9+ MB

# %%
train_df.describe()
# Out:
#                 id           Age        Height        Weight          FCVC  \
# count  20758.00000  20758.000000  20758.000000  20758.000000  20758.000000
# mean   10378.50000     23.841804      1.700245     87.887768      2.445908
# std     5992.46278      5.688072      0.087312     26.379443      0.533218
# min        0.00000     14.000000      1.450000     39.000000      1.000000
# 25%     5189.25000     20.000000      1.631856     66.000000      2.000000
# 50%    10378.50000     22.815416      1.700000     84.064875      2.393837
# 75%    15567.75000     26.000000      1.762887    111.600553      3.000000
# max    20757.00000     61.000000      1.975663    165.057269      3.000000
#
#                 NCP          CH2O           FAF           TUE
# count  20758.000000  20758.000000  20758.000000  20758.000000
# mean       2.761332      2.029418      0.981747      0.616756
# std        0.705375      0.608467      0.838302      0.602113
# min        1.000000      1.000000      0.000000      0.000000
# 25%        3.000000      1.792022      0.008013      0.000000
# 50%        3.000000      2.000000      1.000000      0.573887
# 75%        3.000000      2.549617      1.587406      1.000000
# max        4.000000      3.000000      3.000000      2.000000

# %%
train_df.isnull().sum()
# Out:
# id                                0
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
train_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ----------------------------
# ----------------------------
# ----------------------------

# %% [markdown]
# ### **Basic Statistical Overview**
# - Summary Statistical : **describe()**

# %%
train_df.describe()
# Out:
#                 id           Age        Height        Weight          FCVC  \
# count  20758.00000  20758.000000  20758.000000  20758.000000  20758.000000
# mean   10378.50000     23.841804      1.700245     87.887768      2.445908
# std     5992.46278      5.688072      0.087312     26.379443      0.533218
# min        0.00000     14.000000      1.450000     39.000000      1.000000
# 25%     5189.25000     20.000000      1.631856     66.000000      2.000000
# 50%    10378.50000     22.815416      1.700000     84.064875      2.393837
# 75%    15567.75000     26.000000      1.762887    111.600553      3.000000
# max    20757.00000     61.000000      1.975663    165.057269      3.000000
#
#                 NCP          CH2O           FAF           TUE
# count  20758.000000  20758.000000  20758.000000  20758.000000
# mean       2.761332      2.029418      0.981747      0.616756
# std        0.705375      0.608467      0.838302      0.602113
# min        1.000000      1.000000      0.000000      0.000000
# 25%        3.000000      1.792022      0.008013      0.000000
# 50%        3.000000      2.000000      1.000000      0.573887
# 75%        3.000000      2.549617      1.587406      1.000000
# max        4.000000      3.000000      3.000000      2.000000

# %%
train_df.hist(bins=15, figsize=(16, 10), color='red', edgecolor='black')

# Set titles and labels for each subplot
plt.suptitle('Histograms of Columns', fontsize=16)
plt.subplots_adjust(hspace=0.5)  # Add space between plots
plt.show()

# %% [markdown]
# ## Transform Data

# %%
label = LabelEncoder()

# %%
obj = train_df.select_dtypes(include='object')
non_obj = train_df.select_dtypes(exclude='object')

# %%
for col in range(0,obj.shape[1]):
    obj.iloc[:,col]=label.fit_transform(obj.iloc[:,col])
obj= obj.astype(int)

# %%
df=pd.concat([non_obj,obj],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20758 entries, 0 to 20757
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              20758 non-null  int64
#  1   Age                             20758 non-null  float64
#  2   Height                          20758 non-null  float64
#  3   Weight                          20758 non-null  float64
#  4   FCVC                            20758 non-null  float64
#  5   NCP                             20758 non-null  float64
#  6   CH2O                            20758 non-null  float64
#  7   FAF                             20758 non-null  float64
#  8   TUE                             20758 non-null  float64
#  9   Gender                          20758 non-null  int32
#  10  family_history_with_overweight  20758 non-null  int32
#  11  FAVC                            20758 non-null  int32
#  12  CAEC                            20758 non-null  int32
#  13  SMOKE                           20758 non-null  int32
#  14  SCC                             20758 non-null  int32
#  15  CALC                            20758 non-null  int32
#  16  MTRANS                          20758 non-null  int32
#  17  NObeyesdad                      20758 non-null  int32
# dtypes: float64(8), int32(9), int64(1)
# memory usage: 2.1 MB

# %%
test_df.head()
# Out:
#       id  Gender        Age    Height      Weight  \
# 0  20758    Male  26.899886  1.848294  120.644178
# 1  20759  Female  21.000000  1.600000   66.000000
# 2  20760  Female  26.000000  1.643355  111.600553
# 3  20761    Male  20.979254  1.553127  103.669116
# 4  20762  Female  26.000000  1.627396  104.835346
#
#   family_history_with_overweight FAVC      FCVC       NCP       CAEC SMOKE  \
# 0                            yes  yes  2.938616  3.000000  Sometimes    no
# 1                            yes  yes  2.000000  1.000000  Sometimes    no
# 2                            yes  yes  3.000000  3.000000  Sometimes    no
# 3                            yes  yes  2.000000  2.977909  Sometimes    no
# 4                            yes  yes  3.000000  3.000000  Sometimes    no
#
#        CH2O SCC       FAF       TUE       CALC                 MTRANS
# 0  2.825629  no  0.855400  0.000000  Sometimes  Public_Transportation
# 1  3.000000  no  1.000000  0.000000  Sometimes  Public_Transportation
# 2  2.621877  no  0.000000  0.250502  Sometimes  Public_Transportation
# 3  2.786417  no  0.094851  0.000000  Sometimes  Public_Transportation
# 4  2.653531  no  0.000000  0.741069  Sometimes  Public_Transportation

# %%
# for test
objj = test_df.select_dtypes(include='object')
non_objj = test_df.select_dtypes(exclude='object')

# %%
# for test
for col in range(0,objj.shape[1]):
    objj.iloc[:,col]=label.fit_transform(objj.iloc[:,col])
objj= objj.astype(int)

# %%
df2= pd.concat([non_objj,objj],axis=1)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13840 entries, 0 to 13839
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              13840 non-null  int64
#  1   Age                             13840 non-null  float64
#  2   Height                          13840 non-null  float64
#  3   Weight                          13840 non-null  float64
#  4   FCVC                            13840 non-null  float64
#  5   NCP                             13840 non-null  float64
#  6   CH2O                            13840 non-null  float64
#  7   FAF                             13840 non-null  float64
#  8   TUE                             13840 non-null  float64
#  9   Gender                          13840 non-null  int32
#  10  family_history_with_overweight  13840 non-null  int32
#  11  FAVC                            13840 non-null  int32
#  12  CAEC                            13840 non-null  int32
#  13  SMOKE                           13840 non-null  int32
#  14  SCC                             13840 non-null  int32
#  15  CALC                            13840 non-null  int32
#  16  MTRANS                          13840 non-null  int32
# dtypes: float64(8), int32(8), int64(1)
# memory usage: 1.4 MB

# %%
scaler=StandardScaler()

# %%
# for train
sc1=df[['Age']]
sc2=df[['Weight']]
df['Age']=scaler.fit_transform(sc1)
df['Weight']=scaler.fit_transform(sc2)

# %%
df.head()
# Out:
#    id       Age    Height    Weight      FCVC       NCP      CH2O       FAF  \
# 0   0  0.105699  1.699998 -0.235713  2.000000  2.983297  2.763573  0.000000
# 1   1 -1.027052  1.560000 -1.170931  2.000000  3.000000  2.000000  1.000000
# 2   2 -1.027052  1.711460 -1.430012  1.880534  1.411685  1.910378  0.866045
# 3   3 -0.507929  1.710730  1.644770  3.000000  3.000000  1.674061  1.467863
# 4   4  1.371197  1.914186  0.224054  2.679664  1.971472  1.979848  1.967973
#
#         TUE  Gender  family_history_with_overweight  FAVC  CAEC  SMOKE  SCC  \
# 0  0.976473       1                               1     1     2      0    0
# 1  1.000000       0                               1     1     1      0    0
# 2  1.673584       0                               1     1     2      0    0
# 3  0.780199       0                               1     1     2      0    0
# 4  0.931721       1                               1     1     2      0    0
#
#    CALC  MTRANS  NObeyesdad
# 0     1       3           6
# 1     2       0           1
# 2     2       3           0
# 3     1       3           4
# 4     1       3           6

# %%
# for test 
sc1=df2[['Age']]
sc2=df2[['Weight']]
df2['Age']=scaler.fit_transform(sc1)
df2['Weight']=scaler.fit_transform(sc2)

# %%
df2.head()
# Out:
#       id       Age    Height    Weight      FCVC       NCP      CH2O  \
# 0  20758  0.508163  1.848294  1.273786  2.938616  3.000000  2.825629
# 1  20759 -0.509128  1.600000 -0.818988  2.000000  1.000000  3.000000
# 2  20760  0.353000  1.643355  0.927432  3.000000  3.000000  2.621877
# 3  20761 -0.512705  1.553127  0.623672  2.000000  2.977909  2.786417
# 4  20762  0.353000  1.627396  0.668336  3.000000  3.000000  2.653531
#
#         FAF       TUE  Gender  family_history_with_overweight  FAVC  CAEC  \
# 0  0.855400  0.000000       1                               1     1     2
# 1  1.000000  0.000000       0                               1     1     2
# 2  0.000000  0.250502       0                               1     1     2
# 3  0.094851  0.000000       1                               1     1     2
# 4  0.000000  0.741069       0                               1     1     2
#
#    SMOKE  SCC  CALC  MTRANS
# 0      0    0     2       3
# 1      0    0     2       3
# 2      0    0     2       3
# 3      0    0     2       3
# 4      0    0     2       3

# %% [markdown]
# ## Creating model

# %%
x=df.drop(['NObeyesdad','id'],axis=1)
y=df['NObeyesdad']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1234)

# %%
m1=LogisticRegression()
m2=SVC()
m3=RandomForestClassifier()
m4=GradientBoostingClassifier()
m5=KNeighborsClassifier()
m6=XGBClassifier()
m7=GaussianNB()

# %%
def class_report(model):
    model.fit(x_train,y_train)
    pred = model.predict(x_test)
    print(classification_report(pred,y_test))

# %%
class_report(m1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.80      0.83       555
#            1       0.70      0.71      0.70       569
#            2       0.82      0.78      0.80       616
#            3       0.96      0.93      0.95       672
#            4       1.00      1.00      1.00       830
#            5       0.61      0.68      0.64       439
#            6       0.60      0.65      0.62       471
#
#     accuracy                           0.81      4152
#    macro avg       0.79      0.79      0.79      4152
# weighted avg       0.82      0.81      0.82      4152

# %%
class_report(m2)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.87      0.91       560
#            1       0.78      0.83      0.80       545
#            2       0.84      0.81      0.82       611
#            3       0.97      0.95      0.96       661
#            4       0.99      1.00      1.00       828
#            5       0.66      0.72      0.69       446
#            6       0.69      0.69      0.69       501
#
#     accuracy                           0.86      4152
#    macro avg       0.84      0.84      0.84      4152
# weighted avg       0.86      0.86      0.86      4152

# %%
class_report(m3)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94       498
#            1       0.91      0.85      0.88       613
#            2       0.89      0.90      0.89       583
#            3       0.97      0.97      0.97       651
#            4       0.99      1.00      1.00       827
#            5       0.74      0.80      0.77       454
#            6       0.82      0.79      0.80       526
#
#     accuracy                           0.90      4152
#    macro avg       0.89      0.89      0.89      4152
# weighted avg       0.90      0.90      0.90      4152

# %%
class_report(m4)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.94       501
#            1       0.91      0.86      0.88       615
#            2       0.91      0.91      0.91       585
#            3       0.98      0.97      0.97       652
#            4       0.99      1.00      1.00       826
#            5       0.75      0.81      0.78       455
#            6       0.83      0.81      0.82       518
#
#     accuracy                           0.91      4152
#    macro avg       0.90      0.90      0.90      4152
# weighted avg       0.91      0.91      0.91      4152

# %%
class_report(m5)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.77      0.81       565
#            1       0.66      0.62      0.64       616
#            2       0.81      0.72      0.76       664
#            3       0.96      0.94      0.95       661
#            4       0.99      1.00      0.99       827
#            5       0.46      0.58      0.51       396
#            6       0.56      0.66      0.61       423
#
#     accuracy                           0.78      4152
#    macro avg       0.76      0.75      0.75      4152
# weighted avg       0.79      0.78      0.79      4152

# %%
class_report(m6)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.95      0.94       495
#            1       0.91      0.87      0.89       605
#            2       0.90      0.90      0.90       589
#            3       0.97      0.97      0.97       651
#            4       0.99      1.00      1.00       826
#            5       0.79      0.82      0.80       475
#            6       0.83      0.82      0.82       511
#
#     accuracy                           0.91      4152
#    macro avg       0.90      0.90      0.90      4152
# weighted avg       0.91      0.91      0.91      4152

# %%
class_report(m7)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.69      0.76       621
#            1       0.46      0.66      0.54       402
#            2       0.65      0.40      0.49       962
#            3       0.94      0.73      0.82       836
#            4       0.99      0.95      0.97       864
#            5       0.27      0.59      0.37       224
#            6       0.25      0.53      0.34       243
#
#     accuracy                           0.67      4152
#    macro avg       0.63      0.65      0.61      4152
# weighted avg       0.74      0.67      0.69      4152

# %% [markdown]
# ## Get the best params for increasing accuracy

# %% [markdown]
# ### m3=RandomForestClassifier()
# ### m4=GradientBoostingClassifier()
# ### m6=XGBClassifier()

# %%
params_grid={
           'n_estimators':[100,200,300],
           'learning_rate':[0.1,0.01,0.001],
           'max_depth' : [3,5,7]
        }

scorer='accuracy'

# %%
model3=GridSearchCV(m3, params_grid, scoring=scorer,n_jobs=-1)
model3.fit(x_train,y_train)
print(model3.best_params_)
print(model3.best_score_)
# Out:
# '\nmodel3=GridSearchCV(m3, params_grid, scoring=scorer,n_jobs=-1)\nmodel3.fit(x_train,y_train)\nprint(model3.best_params_)\nprint(model3.best_score_)\n'

# %%
model4=GridSearchCV(m4, params_grid, scoring=scorer,n_jobs=-1)
model4.fit(x_train,y_train)
print(model4.best_params_)
print(model4.best_score_)

# %%
model6=GridSearchCV(m6, params_grid, scoring=scorer,n_jobs=-1)
model6.fit(x_train,y_train)
print(model6.best_params_)
print(model6.best_score_)

# %% [markdown]
# For test data

# %%
testx=df2.drop('id',axis=1)

# %%
pred = m6.predict(testx)

# %%
resule_test=pd.DataFrame({'id':df2['id'],
                          'NObeyesdad':pred})

# %%
#resule_test['NObeyesdad']=label.inverse_transform(pred)

# %%
resule_test
# Out:
#           id  NObeyesdad
# 0      20758           3
# 1      20759           5
# 2      20760           4
# 3      20761           2
# 4      20762           4
# ...      ...         ...
# 13835  34593           6
# 13836  34594           5
# 13837  34595           0
# 13838  34596           1
# 13839  34597           3
#
# [13840 rows x 2 columns]

# %%
resule_test.to_csv('submission.csv',index=False)
