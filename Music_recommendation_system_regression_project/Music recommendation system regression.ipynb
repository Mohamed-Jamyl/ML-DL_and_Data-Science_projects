# %% [markdown]
# # <center><strong>Music Recommendation System using Spotify</strong></center>

# %% [markdown]
# ###### **By Mohamed Jamyl**

# %%
from IPython.display import Image
Image(filename='sp.png')

# %% [markdown]
# --------------------------------
# --------------------------------
# --------------------------------

# %% [markdown]
# ## **Import Libraries**

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------

# %% [markdown]
# ## **Exploratory Data Analysis (EDA)**

# %% [markdown]
# ### **Initial	Data Understanding**

# %% [markdown]
#  - **Data loading and Inspection**
#  - **Data Types**
#  - **Missing Values**
#  - **Duplicates**

# %%
# <center><strong> text </strong></center>

df = pd.read_csv('Music Recommendation System using Spotify Dataset.csv')

# %%
df
# Out:
#         valence  year  acousticness  \
# 0        0.0594  1921       0.98200
# 1        0.9630  1921       0.73200
# 2        0.0394  1921       0.96100
# 3        0.1650  1921       0.96700
# 4        0.2530  1921       0.95700
# ...         ...   ...           ...
# 170648   0.6080  2020       0.08460
# 170649   0.7340  2020       0.20600
# 170650   0.6370  2020       0.10100
# 170651   0.1950  2020       0.00998
# 170652   0.6420  2020       0.13200
#
#                                                   artists  danceability  \
# 0       ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                          ['Dennis Day']         0.819
# 2       ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                        ['Frank Parker']         0.275
# 4                                          ['Phil Regan']         0.418
# ...                                                   ...           ...
# 170648  ['Anuel AA', 'Daddy Yankee', 'KAROL G', 'Ozuna...         0.786
# 170649                                       ['Ashnikko']         0.717
# 170650                                        ['MAMAMOO']         0.634
# 170651                                         ['Eminem']         0.671
# 170652                              ['KEVVO', 'J Balvin']         0.856
#
#         duration_ms  energy  explicit                      id  \
# 0            831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz
# 1            180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8
# 2            500062   0.166         0  1o6I8BglA6ylDMrIELygv1
# 3            210000   0.309         0  3ftBPsC5vPBKxYSee08FDH
# 4            166693   0.193         0  4d6HGyGT8e121BsdKmw9v6
# ...             ...     ...       ...                     ...
# 170648       301714   0.808         0  0KkIkfsLEJbrcIhYsCL7L5
# 170649       150654   0.753         0  0OStKKAuXlxA0fMH54Qs6E
# 170650       211280   0.858         0  4BZXVFYCb76Q0Klojq4piV
# 170651       337147   0.623         1  5SiZJoLXp3WOl3J4C8IK0d
# 170652       189507   0.721         1  7HmnJHfs0BkFzX4x8j0hkl
#
#         instrumentalness  key  liveness  loudness  mode  \
# 0               0.878000   10    0.6650   -20.096     1
# 1               0.000000    7    0.1600   -12.441     1
# 2               0.913000    3    0.1010   -14.850     1
# 3               0.000028    5    0.3810    -9.316     1
# 4               0.000002    3    0.2290   -10.096     1
# ...                  ...  ...       ...       ...   ...
# 170648          0.000289    7    0.0822    -3.702     1
# 170649          0.000000    7    0.1010    -6.020     1
# 170650          0.000009    4    0.2580    -2.226     0
# 170651          0.000008    2    0.6430    -7.161     1
# 170652          0.004710    7    0.1820    -4.928     1
#
#                                                      name  popularity  \
# 0       Piano Concerto No. 3 in D Minor, Op. 30: III. ...           4
# 1                                 Clancy Lowered the Boom           5
# 2                                               Gati Bali           5
# 3                                               Danny Boy           3
# 4                             When Irish Eyes Are Smiling           2
# ...                                                   ...         ...
# 170648                                              China          72
# 170649                        Halloweenie III: Seven Days          68
# 170650                                                AYA          76
# 170651                                           Darkness          70
# 170652                    Billetes Azules (with J Balvin)          74
#
#        release_date  speechiness    tempo
# 0              1921       0.0366   80.954
# 1              1921       0.4150   60.936
# 2              1921       0.0339  110.339
# 3              1921       0.0354  100.109
# 4              1921       0.0380  101.665
# ...             ...          ...      ...
# 170648    5/29/2020       0.0881  105.029
# 170649   10/23/2020       0.0605  137.936
# 170650    11/3/2020       0.0809   91.688
# 170651    1/17/2020       0.3080   75.055
# 170652   10/16/2020       0.1080   94.991
#
# [170653 rows x 19 columns]

# %%
df.shape
# Out:
# (170653, 19)

# %%
df.columns
# Out:
# Index(['valence', 'year', 'acousticness', 'artists', 'danceability',
#        'duration_ms', 'energy', 'explicit', 'id', 'instrumentalness', 'key',
#        'liveness', 'loudness', 'mode', 'name', 'popularity', 'release_date',
#        'speechiness', 'tempo'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170653 entries, 0 to 170652
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   valence           170653 non-null  float64
#  1   year              170653 non-null  int64
#  2   acousticness      170653 non-null  float64
#  3   artists           170653 non-null  object
#  4   danceability      170653 non-null  float64
#  5   duration_ms       170653 non-null  int64
#  6   energy            170653 non-null  float64
#  7   explicit          170653 non-null  int64
#  8   id                170653 non-null  object
#  9   instrumentalness  170653 non-null  float64
#  10  key               170653 non-null  int64
#  11  liveness          170653 non-null  float64
#  12  loudness          170653 non-null  float64
#  13  mode              170653 non-null  int64
#  14  name              170653 non-null  object
#  15  popularity        170653 non-null  int64
#  16  release_date      170653 non-null  object
#  17  speechiness       170653 non-null  float64
#  18  tempo             170653 non-null  float64
# dtypes: float64(9), int64(6), object(4)
# memory usage: 24.7+ MB

# %%
df.isnull().sum()
# Out:
# valence             0
# year                0
# acousticness        0
# artists             0
# danceability        0
# duration_ms         0
# energy              0
# explicit            0
# id                  0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# name                0
# popularity          0
# release_date        0
# speechiness         0
# tempo               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# -----------------------------------------

# %% [markdown]
# ### **Basic Statistical Overview**
# - Summary Statistical : **describe()**

# %%
df.describe()
# Out:
#              valence           year   acousticness   danceability  \
# count  170653.000000  170653.000000  170653.000000  170653.000000
# mean        0.528587    1976.787241       0.502115       0.537396
# std         0.263171      25.917853       0.376032       0.176138
# min         0.000000    1921.000000       0.000000       0.000000
# 25%         0.317000    1956.000000       0.102000       0.415000
# 50%         0.540000    1977.000000       0.516000       0.548000
# 75%         0.747000    1999.000000       0.893000       0.668000
# max         1.000000    2020.000000       0.996000       0.988000
#
#         duration_ms         energy       explicit  instrumentalness  \
# count  1.706530e+05  170653.000000  170653.000000     170653.000000
# mean   2.309483e+05       0.482389       0.084575          0.167010
# std    1.261184e+05       0.267646       0.278249          0.313475
# min    5.108000e+03       0.000000       0.000000          0.000000
# 25%    1.698270e+05       0.255000       0.000000          0.000000
# 50%    2.074670e+05       0.471000       0.000000          0.000216
# 75%    2.624000e+05       0.703000       0.000000          0.102000
# max    5.403500e+06       1.000000       1.000000          1.000000
#
#                  key       liveness       loudness           mode  \
# count  170653.000000  170653.000000  170653.000000  170653.000000
# mean        5.199844       0.205839     -11.467990       0.706902
# std         3.515094       0.174805       5.697943       0.455184
# min         0.000000       0.000000     -60.000000       0.000000
# 25%         2.000000       0.098800     -14.615000       0.000000
# 50%         5.000000       0.136000     -10.580000       1.000000
# 75%         8.000000       0.261000      -7.183000       1.000000
# max        11.000000       1.000000       3.855000       1.000000
#
#           popularity    speechiness          tempo
# count  170653.000000  170653.000000  170653.000000
# mean       31.431794       0.098393     116.861590
# std        21.826615       0.162740      30.708533
# min         0.000000       0.000000       0.000000
# 25%        11.000000       0.034900      93.421000
# 50%        33.000000       0.045000     114.729000
# 75%        48.000000       0.075600     135.537000
# max       100.000000       0.970000     243.507000

# %%
df.select_dtypes(include='object').describe()
# Out:
#                      artists                      id             name  \
# count                 170653                  170653           170653
# unique                 34088                  170653           133637
# top     ['Эрнест Хемингуэй']  7HmnJHfs0BkFzX4x8j0hkl  White Christmas
# freq                    1211                       1               73
#
#        release_date
# count        170653
# unique        11244
# top            1945
# freq           1446

# %%
df.hist(bins=15, figsize=(16, 10), color='red', edgecolor='black')

# Set titles and labels for each subplot
plt.suptitle('Histograms of Columns', fontsize=16)
plt.subplots_adjust(hspace=0.5)  # Add space between plots
plt.show()

# %% [markdown]
# --------------------------------

# %% [markdown]
# - Summary Statistical : **value_counts()**

# %%
df["release_date"].value_counts()
# Out:
# release_date
# 1945         1446
# 1949         1247
# 1948         1127
# 1926         1099
# 1935         1078
#              ...
# 8/16/2018       1
# 3/27/2018       1
# 4/29/2018       1
# 8/29/2018       1
# 8/9/2018        1
# Name: count, Length: 11244, dtype: int64

# %%
df['year'].value_counts()
# Out:
# year
# 2018    2103
# 2020    2030
# 2011    2017
# 2010    2016
# 2001    2005
#         ...
# 1925     278
# 1924     236
# 1923     185
# 1921     150
# 1922      71
# Name: count, Length: 100, dtype: int64

# %%
df['explicit'].value_counts()
# Out:
# explicit
# 0    156220
# 1     14433
# Name: count, dtype: int64

# %%
df['explicit'].value_counts().plot.pie(autopct='%0.2f%%')
plt.show()

# %%
top20_songs=df['name'].value_counts().sort_values(ascending=False)[:20]
top20_songs
# Out:
# name
# White Christmas       73
# Winter Wonderland     63
# Summertime            56
# Jingle Bells          53
# Overture              46
# Silent Night          45
# Home                  40
# Silver Bells          36
# The Christmas Song    36
# Sleigh Ride           35
# Stay                  33
# You                   33
# Hold On               31
# Autumn Leaves         31
# Forever               31
# Runaway               31
# Intro                 31
# Angel                 30
# I Love You            30
# Stardust              30
# Name: count, dtype: int64

# %%
nameDict = top20_songs.to_dict()
nameDict
# Out:
# {'White Christmas': 73,
#  'Winter Wonderland': 63,
#  'Summertime': 56,
#  'Jingle Bells': 53,
#  'Overture': 46,
#  'Silent Night': 45,
#  'Home': 40,
#  'Silver Bells': 36,
#  'The Christmas Song': 36,
#  'Sleigh Ride': 35,
#  'Stay': 33,
#  'You': 33,
#  'Hold On': 31,
#  'Autumn Leaves': 31,
#  'Forever': 31,
#  'Runaway': 31,
#  'Intro': 31,
#  'Angel': 30,
#  'I Love You': 30,
#  'Stardust': 30}

# %%
song_names = [f'{i}' for i in top20_songs.keys()]  
song_names
# Out:
# ['White Christmas',
#  'Winter Wonderland',
#  'Summertime',
#  'Jingle Bells',
#  'Overture',
#  'Silent Night',
#  'Home',
#  'Silver Bells',
#  'The Christmas Song',
#  'Sleigh Ride',
#  'Stay',
#  'You',
#  'Hold On',
#  'Autumn Leaves',
#  'Forever',
#  'Runaway',
#  'Intro',
#  'Angel',
#  'I Love You',
#  'Stardust']

# %%
plt.style.use('ggplot')
plt.figure(figsize=(14, 5))

plt.plot(top20_songs, marker='o', color='red', linestyle='-', linewidth=2, markersize=8)
plt.xticks(ticks=range(len(song_names)), labels=song_names, rotation=90, fontsize=10)  
plt.title('The best 20 songs', fontsize=16)
plt.ylabel('Value', fontsize=12)

for i, value in enumerate(top20_songs):
    plt.text(i, value + 0.5, str(round(value, 2)), ha='center', fontsize=10, color='black')

plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ------------------------------

# %%
top20MeanPopularity=[df[df['name']==i]['popularity'].mean() for i in list(top20_songs.keys())]
top20MeanPopularity.sort()
top20MeanPopularity
# Out:
# [np.float64(11.23913043478261),
#  np.float64(23.6),
#  np.float64(26.92452830188679),
#  np.float64(27.15068493150685),
#  np.float64(29.451612903225808),
#  np.float64(29.857142857142858),
#  np.float64(30.11111111111111),
#  np.float64(30.8),
#  np.float64(30.841269841269842),
#  np.float64(30.86111111111111),
#  np.float64(31.822222222222223),
#  np.float64(35.0),
#  np.float64(41.83870967741935),
#  np.float64(45.86666666666667),
#  np.float64(47.54838709677419),
#  np.float64(47.825),
#  np.float64(47.878787878787875),
#  np.float64(48.83870967741935),
#  np.float64(49.0),
#  np.float64(49.24242424242424)]

# %%
song_names = [f'Song {i+1}' for i in range(len(top20MeanPopularity))]  

plt.style.use('ggplot')
plt.figure(figsize=(14, 5))

plt.plot(top20MeanPopularity, marker='o', color='red', linestyle='-', linewidth=2, markersize=8)
plt.xticks(ticks=range(len(song_names)), labels=song_names, rotation=90, fontsize=10)  
plt.title('The best 20 mean popularity', fontsize=16)
plt.ylabel('Mean Popularity', fontsize=12)

for i, value in enumerate(top20MeanPopularity):
    plt.text(i, value + 0.5, str(round(value, 2)), ha='center', fontsize=10, color='black')

plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ---------------------------------------

# %%
top20_artist = df['artists'].value_counts().sort_values(ascending=False)[:20]
top20_artist
# Out:
# artists
# ['Эрнест Хемингуэй']                   1211
# ['Эрих Мария Ремарк']                  1068
# ['Francisco Canaro']                    942
# ['Frank Sinatra']                       630
# ['Ignacio Corsini']                     628
# ['Elvis Presley']                       504
# ['Johnny Cash']                         484
# ['Bob Dylan']                           474
# ['The Rolling Stones']                  471
# ['The Beach Boys']                      455
# ['Francisco Canaro', 'Charlo']          453
# ['Fleetwood Mac']                       437
# ['Dean Martin']                         420
# ['The Beatles']                         407
# ['Queen']                               406
# ['Billie Holiday']                      404
# ['Georgette Heyer', 'Irina Salkow']     395
# ['Miles Davis']                         394
# ['Ella Fitzgerald']                     365
# ['Lead Belly']                          337
# Name: count, dtype: int64

# %% [markdown]
# ---------------------------------------
# ---------------------------------------

# %% [markdown]
# ## **Distribution of Variables**
#
# - **Numerical Features (KDE)**

# %%
sns.set(style="whitegrid")
for	col	in	df.select_dtypes('number').columns:
    plt.figure(figsize=(12,	4))		
    sns.kdeplot(df[col], fill=True,	color='blue', alpha=0.6)		
    plt.title(f'Kernel Density Estimate	(KDE) - {col}',	fontsize=16)		
    plt.xlabel(col,	fontsize=12)		
    plt.ylabel('Density', fontsize=12)	
    plt.grid(True, linestyle='--', alpha=0.7)		
    plt.tight_layout()		
    plt.show()
# Out:
# C:\Users\RPC\AppData\Local\Temp\ipykernel_8220\2997416000.py:9: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   plt.tight_layout()
# c:\Users\RPC\.ai-navigator\conda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\RPC\AppData\Local\Temp\ipykernel_8220\2997416000.py:9: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   plt.tight_layout()
# c:\Users\RPC\.ai-navigator\conda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\RPC\AppData\Local\Temp\ipykernel_8220\2997416000.py:9: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   plt.tight_layout()
# c:\Users\RPC\.ai-navigator\conda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\RPC\AppData\Local\Temp\ipykernel_8220\2997416000.py:9: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   plt.tight_layout()
# c:\Users\RPC\.ai-navigator\conda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\RPC\AppData\Local\Temp\ipykernel_8220\2997416000.py:9: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   plt.tight_layout()
# c:\Users\RPC\.ai-navigator\conda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\RPC\AppData\Local\Temp\ipykernel_8220\2997416000.py:9: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   plt.tight_layout()
# c:\Users\RPC\.ai-navigator\conda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\RPC\AppData\Local\Temp\ipykernel_8220\2997416000.py:9: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   plt.tight_layout()
# c:\Users\RPC\.ai-navigator\conda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\RPC\AppData\Local\Temp\ipykernel_8220\2997416000.py:9: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   plt.tight_layout()
# c:\Users\RPC\.ai-navigator\conda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\RPC\AppData\Local\Temp\ipykernel_8220\2997416000.py:9: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   plt.tight_layout()
# c:\Users\RPC\.ai-navigator\conda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\RPC\AppData\Local\Temp\ipykernel_8220\2997416000.py:9: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   plt.tight_layout()
# c:\Users\RPC\.ai-navigator\conda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\RPC\AppData\Local\Temp\ipykernel_8220\2997416000.py:9: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   plt.tight_layout()
# c:\Users\RPC\.ai-navigator\conda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\RPC\AppData\Local\Temp\ipykernel_8220\2997416000.py:9: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   plt.tight_layout()
# c:\Users\RPC\.ai-navigator\conda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\RPC\AppData\Local\Temp\ipykernel_8220\2997416000.py:9: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   plt.tight_layout()
# c:\Users\RPC\.ai-navigator\conda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\RPC\AppData\Local\Temp\ipykernel_8220\2997416000.py:9: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   plt.tight_layout()
# c:\Users\RPC\.ai-navigator\conda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\RPC\AppData\Local\Temp\ipykernel_8220\2997416000.py:9: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   plt.tight_layout()
# c:\Users\RPC\.ai-navigator\conda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# -----------------------------

# %% [markdown]
# ### **Log Transformation**

# %%
sns.set(style="whitegrid")
for	col	in df[['duration_ms','instrumentalness','speechiness']]:
    plt.figure(figsize=(12,	4))		
    sns.kdeplot(np.log(df[col]).replace(-np.inf,1e-6), fill=True, color='green', alpha=0.6)		
    plt.title(f'Kernel Density Estimate	(KDE) - {col}',	fontsize=16)		
    plt.xlabel(col,	fontsize=12)		
    plt.ylabel('Density', fontsize=12)	
    plt.grid(True, linestyle='--', alpha=0.7)		
    plt.tight_layout()		
    plt.show()
# Out:
# C:\Users\RPC\AppData\Local\Temp\ipykernel_8220\1169216085.py:9: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   plt.tight_layout()
# c:\Users\RPC\.ai-navigator\conda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\RPC\.ai-navigator\conda\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\RPC\AppData\Local\Temp\ipykernel_8220\1169216085.py:9: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   plt.tight_layout()
# c:\Users\RPC\.ai-navigator\conda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\RPC\.ai-navigator\conda\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\RPC\AppData\Local\Temp\ipykernel_8220\1169216085.py:9: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   plt.tight_layout()
# c:\Users\RPC\.ai-navigator\conda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# --------------------------

# %% [markdown]
# ### **Correlation**

# %%
plt.figure(figsize=(14,	7))	
sns.heatmap(df.select_dtypes(include='number').corr(), annot=True)
plt.show()

# %% [markdown]
# ##### There is a high positive correlation (0.86) between **year** and **popularity**

# %%
fig,ax = plt.subplots()
fig.set_size_inches(14, 5)
sns.regplot(x="year", y="popularity", data=df,ax=ax)
plt.show()

# %% [markdown]
# -------------------------------------

# %% [markdown]
# ##### There is a high positive correlation (0.78) between **energy** and **loudness**

# %%
fig,ax = plt.subplots()
fig.set_size_inches(14, 5)
sns.regplot(x="energy", y="loudness", data=df,ax=ax)
plt.show()

# %% [markdown]
# -------------------------

# %% [markdown]
# ##### There is a high negative correlation (-0.75) between **energy** and **acousticness**

# %%
fig,ax = plt.subplots()
fig.set_size_inches(14, 5)
sns.regplot(x="acousticness", y="energy", data=df,ax=ax)
plt.show()

# %% [markdown]
# ----------------------------

# %% [markdown]
# ##### There is a high negative correlation (-0.61) between **year** and **acousticness**

# %%
fig,ax = plt.subplots()
fig.set_size_inches(14, 5)
sns.regplot(x="year", y="acousticness", data=df,ax=ax)
plt.show()

# %% [markdown]
# ---------------------------------
# ---------------------------------

# %% [markdown]
# ## **Detect Outliers**

# %%
fig, axes = plt.subplots(nrows=1,ncols=1)
fig.set_size_inches(8, 8)
sns.boxplot(data=df,y="popularity",orient="v",ax=axes)
# Out:
# <Axes: ylabel='popularity'>

# %%
 #	Target Variable	Analysis
 #	Relationship with Predictors (scatter plots, box Plots against the target)

for col in df.select_dtypes('number').drop('popularity', axis=1):
    top_10_categs = df[col].value_counts().index[:10]
    filtered_df = df[df[col].isin(top_10_categs)]

    plt.figure(figsize=(14, 6))
    
    sns.boxplot(x=filtered_df[col], y=filtered_df['popularity'], palette="Set2")
    
    plt.title(f'{col} vs Popularity')
    plt.show()
# Out:
# C:\Users\RPC\AppData\Local\Temp\ipykernel_8220\1395385573.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=filtered_df[col], y=filtered_df['popularity'], palette="Set2")
# C:\Users\RPC\AppData\Local\Temp\ipykernel_8220\1395385573.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=filtered_df[col], y=filtered_df['popularity'], palette="Set2")
# C:\Users\RPC\AppData\Local\Temp\ipykernel_8220\1395385573.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=filtered_df[col], y=filtered_df['popularity'], palette="Set2")
# C:\Users\RPC\AppData\Local\Temp\ipykernel_8220\1395385573.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=filtered_df[col], y=filtered_df['popularity'], palette="Set2")
# C:\Users\RPC\AppData\Local\Temp\ipykernel_8220\1395385573.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=filtered_df[col], y=filtered_df['popularity'], palette="Set2")
# C:\Users\RPC\AppData\Local\Temp\ipykernel_8220\1395385573.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=filtered_df[col], y=filtered_df['popularity'], palette="Set2")
# C:\Users\RPC\AppData\Local\Temp\ipykernel_8220\1395385573.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=filtered_df[col], y=filtered_df['popularity'], palette="Set2")
# C:\Users\RPC\AppData\Local\Temp\ipykernel_8220\1395385573.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=filtered_df[col], y=filtered_df['popularity'], palette="Set2")
# C:\Users\RPC\AppData\Local\Temp\ipykernel_8220\1395385573.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=filtered_df[col], y=filtered_df['popularity'], palette="Set2")
# C:\Users\RPC\AppData\Local\Temp\ipykernel_8220\1395385573.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=filtered_df[col], y=filtered_df['popularity'], palette="Set2")
# C:\Users\RPC\AppData\Local\Temp\ipykernel_8220\1395385573.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=filtered_df[col], y=filtered_df['popularity'], palette="Set2")
# C:\Users\RPC\AppData\Local\Temp\ipykernel_8220\1395385573.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=filtered_df[col], y=filtered_df['popularity'], palette="Set2")
# C:\Users\RPC\AppData\Local\Temp\ipykernel_8220\1395385573.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=filtered_df[col], y=filtered_df['popularity'], palette="Set2")
# C:\Users\RPC\AppData\Local\Temp\ipykernel_8220\1395385573.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=filtered_df[col], y=filtered_df['popularity'], palette="Set2")

# %% [markdown]
# ------------------------------------------
# ------------------------------------------

# %% [markdown]
# ## **Feature Extraction**

# %%
# df['popularity'].value_counts().sort_values(ascending=True)

# %%
# df['year'].unique()

# %%
# sortOrder = [1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931,
#        1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942,
#        1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953,
#        1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964,
#        1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975,
#        1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986,
#        1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997,
#        1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008,
#        2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019,
#        2020]

# yearAggregated = pd.DataFrame(df.groupby("year")["popularity"].sum()).reset_index()

# missing_years = set(sortOrder) - set(yearAggregated['year'])
# valid_sortOrder = [year for year in sortOrder if year in yearAggregated['year'].values]

# print(yearAggregated['year'].dtype, type(sortOrder[0]))

# yearAggregated['year'] = yearAggregated['year'].astype(int)

# %%
# df['year'].loc[df.popularity == 0].unique()

# %%
# yearAggregated.head()

# %%
# fig,ax= plt.subplots()
# fig.set_size_inches(18,6)
# plt.plot(yearAggregated['year'],yearAggregated['popularity'], color = 'g', marker = 'o')
# plt.title('Popularity by Year')
# plt.xlabel('Year')
# plt.ylabel('Popularity')
# plt.grid()
# plt.show()

# %%
# fig,ax= plt.subplots()
# fig.set_size_inches(18,6)
# plt.bar(yearAggregated['year'],yearAggregated['popularity'], color = 'b')
# plt.title('Popularity by Year')
# plt.xlabel('Year')
# plt.ylabel('Popularity')
# plt.show()

# %%
# df= df.drop(['artists','id','name','release_date'],axis=1)

# %% [markdown]
# ## Creating Model

# %%
# from sklearn.model_selection import train_test_split

# x=df.drop('popularity',axis=1) 
# y=df['popularity']

# x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=1234)

# %%
# from xgboost import XGBRegressor
# from sklearn.linear_model import LinearRegression
# from sklearn.tree import DecisionTreeRegressor

# from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
# import math

# score=[]
# r_2=[]
# rmse=[]
# mae=[]

# def reg(model):
#     model.fit(x_train,y_train)
#     pred = model.predict(x_test)

#     SCORE=model.score(x_test,y_test)
#     R2 = r2_score(y_test,pred)
#     RMSE = math.sqrt(mean_squared_error(y_test,pred))
#     MAE = mean_absolute_error(y_test,pred)
    
#     score.append(SCORE)
#     r_2.append(R2)
#     rmse.append(RMSE)
#     mae.append(MAE)

# %%
# m1=LinearRegression()
# m2=XGBRegressor()

# %%
# Algorithms = ['LinearRegression','XGBRegressor']

# %%
# reg(m1)
# reg(m2)

# %%
# result=pd.DataFrame({'Algorithms':Algorithms,'Score':score,'R2':r_2,'rmse':rmse,'mae':mae})
# result
